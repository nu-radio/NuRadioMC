# %%
from wgan import WGAN
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
tf.compat.v1.disable_eager_execution()  # gp loss won't work with eager
from functools import partial
from NuRadioReco.utilities import fft
from NuRadioReco.utilities import units
from NuRadioReco.framework import base_trace
import sys
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("analyze.py"))))
sys.path.insert(1, '/lustre/fs22/group/radio/dhjelm/')
import data_preprocessing
import analyze

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %%
wgan = WGAN()
# Out:
# Model: "critic"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# signal_input (InputLayer)       [(None, 512, 1)]     0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           signal_input[0][0]
# __________________________________________________________________________________________________
# low_pass_0 (Conv1D)             (None, 256, 1)       14          signal_input[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 257)          0           flatten[0][0]
# __________________________________________________________________________________________________
# high_pass_0 (Conv1D)            (None, 256, 1)       14          signal_input[0][0]
# __________________________________________________________________________________________________
# high_pass_1 (Conv1D)            (None, 128, 1)       14          low_pass_0[0][0]
# __________________________________________________________________________________________________
# low_pass_1 (Conv1D)             (None, 128, 1)       14          low_pass_0[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 257)          0           lambda[0][0]
# __________________________________________________________________________________________________
# w_concat (Concatenate)          (None, 512, 1)       0           high_pass_0[0][0]
#                                                                  high_pass_1[0][0]
#                                                                  low_pass_1[0][0]
# __________________________________________________________________________________________________
# fft_abs (Reshape)               (None, 257, 1)       0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 256, 16)      160         signal_input[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 256, 16)      160         w_concat[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 129, 16)      160         fft_abs[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 16)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 256, 16)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 129, 16)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 256, 16)      32          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 256, 16)      32          leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 129, 16)      32          leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 16)      0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 256, 16)      0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 129, 16)      0           layer_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 256, 16)      2320        dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 256, 16)      2320        dropout_5[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 129, 16)      2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 16)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 256, 16)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 129, 16)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 256, 16)      32          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 256, 16)      32          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 129, 16)      32          leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 16)      0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256, 16)      0           layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 129, 16)      0           layer_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 128, 32)      4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 128, 32)      4640        dropout_6[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 65, 32)       4640        dropout_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 32)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 128, 32)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 65, 32)       0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 128, 32)      64          leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 128, 32)      64          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 65, 32)       64          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 32)      0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128, 32)      0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 65, 32)       0           layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 128, 32)      9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 128, 32)      9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 65, 32)       9248        dropout_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 32)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 128, 32)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 65, 32)       0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 128, 32)      64          leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 128, 32)      64          leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 65, 32)       64          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 32)      0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 32)      0           layer_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 65, 32)       0           layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 64, 64)       18496       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 64, 64)       18496       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 33, 64)       18496       dropout_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 64, 64)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 33, 64)       0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 64, 64)       128         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 64, 64)       128         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 33, 64)       128         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64, 64)       0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64)       0           layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 33, 64)       0           layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 64, 64)       36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 64, 64)       36928       dropout_9[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 33, 64)       36928       dropout_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 64, 64)       0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 33, 64)       0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 64, 64)       128         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 64, 64)       128         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 33, 64)       128         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 32, 2)        1154        layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 32, 2)        1154        layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 17, 2)        1154        layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 2)        0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 32, 2)        0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 17, 2)        0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# time_out (Flatten)              (None, 64)           0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# wavelet_out (Flatten)           (None, 64)           0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# fft_out (Flatten)               (None, 34)           0           leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 162)          0           time_out[0][0]
#                                                                  wavelet_out[0][0]
#                                                                  fft_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            163         concatenate[0][0]
# ==================================================================================================
# Total params: 220,401
# Trainable params: 220,345
# Non-trainable params: 56
# __________________________________________________________________________________________________

# %% [markdown]
# # Data

# %%
dataset = np.load('/lustre/fs22/group/radio/dhjelm/data.npy')
np.random.shuffle(dataset)

# %%
# RMS
rms = data_preprocessing.rms_preprocessing(dataset)

# L1
l1 = data_preprocessing.l1_preprocessing(rms)

# Remove DC-offset
fft_traces = fft.time2freq(l1, 3.2*units.GHz)
no_offset = fft_traces[:,1:len(fft_traces[0])]
data_no_offset = fft.freq2time(no_offset, 3.2*units.GHz)

# Shorten the trace
short = data_no_offset[:,0:512]

# Normalization
normalize = data_preprocessing.normalize(short)

# Set data to the normailzed data
data = normalize

# %%
for i in range(5):
    plt.plot(data[i])
plt.title("Time domain")
plt.show()

for i in range(5):
    plt.plot(abs(fft.time2freq(data[i], 3.2*units.GHz)))
plt.title("Frequency domain")
plt.show()

# %%
# Create arrays for generator and critic loss
generator_loss = []
critic_loss = []

# %%
# Keras throws an error when calculating a loss without having a label -> needed for using the gradient penalty loss
positive_y = np.ones(wgan.batch_size)
negative_y = -positive_y
dummy = np.zeros(wgan.batch_size)

# %%
# Training parameters
EPOCHS = 100
nsamples = len(data)
critic_iterations = 5
iterations_per_epoch = nsamples*2//(wgan.batch_size*critic_iterations)
iters = 0
print(iterations_per_epoch)
print(wgan.batch_size)
# Out:
# 65
# 64

# %%
for epoch in range(EPOCHS):
    
    print("Epoch: ", epoch)

    for iteration in range(iterations_per_epoch):
#         print(iteration)
       
        for j in range(critic_iterations):
            
            # Pick data in batches 
            bunch=data[wgan.batch_size*(j+iteration):wgan.batch_size*(j++iteration+1)]
            bunch = np.expand_dims(bunch, axis=-1)  

            # Generate noise
            noise_batch = np.random.randn(wgan.batch_size, wgan.latent_size)
            noise_batch = np.expand_dims(noise_batch, axis=-1) 

            
            # Train critic
            critic_loss.append(wgan.critic_training.train_on_batch([noise_batch, bunch], [negative_y, positive_y, dummy]))
        

        # Generate noise batch for generator
        noise_batch = np.random.randn(wgan.batch_size, wgan.latent_size)
        noise_batch = np.expand_dims(noise_batch, axis=-1) 
        
        # Train the generator
        generator_loss.append(wgan.generator_training.train_on_batch([noise_batch], [positive_y]))  
        iters+=1
        
        # Printing errors and plotting example traces
        if iters % 300 == 1:
            print("Iteration", iters)
            print("Critic loss:", critic_loss[-1])
            print("Generator loss:", generator_loss[-1])
            
            # Generate signals
            noise = np.random.randn(wgan.batch_size, wgan.latent_size)
            noise = np.expand_dims(noise, axis=-1) 
            generated_signals = wgan.generator.predict_on_batch(noise)
            generated_signals = generated_signals[:,:,0]
            
            
            # Plot data
            
            fig, (ax1, ax2) = plt.subplots(1, 2)
            fig.set_size_inches(18.5, 10.5, forward=True)
            ax1.title.set_text('Time domain')
            ax2.title.set_text('Frequency domain')
            
            

            ax1.plot(data[0], label = "Example trace")
#             plt.plot(np.random.randn(trace_length), label = 'Random noise')
            for i in range(3):
                ax1.plot(generated_signals[i], alpha=0.5)
            
            
            # Plot frequency
            ax2.plot(abs(fft.time2freq(data[0], 3.2*units.GHz)), label = "Example trace")
            for i in range(3):
                ax2.plot(abs(fft.time2freq(generated_signals[i], 3.2*units.GHz)),alpha=0.2)
                
            ax1.legend()
            ax2.legend()
            plt.show()



        
       

        #generated_signal = g.predict_on_batch(np.random.randn(BATCH_SIZE, latent_size))
    
    #print("Critic loss:", critic_loss[-1])
    #print("Generator loss:", generator_loss[-1])
# Out:
# Epoch:  0
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_267682/1395884418.py in <cell line: 1>()
#      18
#      19             # Train critic
# ---> 20             critic_loss.append(wgan.critic_training.train_on_batch([noise_batch, bunch], [negative_y, positive_y, dummy]))
#      21
#      22
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_v1.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1085
#    1086       self._update_sample_weight_modes(sample_weights=sample_weights)
# -> 1087       self._make_train_function()
#    1088       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1089
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/keras/engine/training_v1.py in _make_train_function(self)
#    2007         with K.name_scope('training'):
#    2008           # Training updates
# -> 2009           updates = self.optimizer.get_updates(
#    2010               params=self._collected_trainable_weights, loss=self.total_loss)
#    2011           # Unconditional updates
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in get_updates(self, loss, params)
#     725
#     726   def get_updates(self, loss, params):
# --> 727     grads = self.get_gradients(loss, params)
#     728     grads_and_vars = list(zip(grads, params))
#     729     self._assert_valid_dtypes([
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in get_gradients(self, loss, params)
#     714     with backend.get_graph().as_default(), backend.name_scope(self._name +
#     715                                                               "/gradients"):
# --> 716       grads = gradients.gradients(loss, params)
#     717       for grad, param in zip(grads, params):
#     718         if grad is None:
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients)
#     167   # pylint: disable=protected-access
#     168   with ops.get_default_graph()._mutation_lock():
# --> 169     return gradients_util._GradientsHelper(
#     170         ys, xs, grad_ys, name, colocate_gradients_with_ops,
#     171         gate_gradients, aggregation_method, stop_gradients,
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/gradients_util.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     681                 # If grad_fn was found, do not use SymbolicGradient even for
#     682                 # functions.
# --> 683                 in_grads = _MaybeCompile(grad_scope, op, func_call,
#     684                                          lambda: grad_fn(op, *out_grads))
#     685               else:
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     338
#     339   if not xla_compile:
# --> 340     return grad_fn()  # Exit early
#     341
#     342   # If the gradients are supposed to be compiled separately, we give them a
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/gradients_util.py in <lambda>()
#     682                 # functions.
#     683                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 684                                          lambda: grad_fn(op, *out_grads))
#     685               else:
#     686                 # For function call ops, we add a 'SymbolicGradient'
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/signal/fft_ops.py in _grad(op, grad)
#     353     input_last_dimension = _array_ops.shape(op.inputs[0])[-1]
#     354     mask = _array_ops.concat(
# --> 355         [[1.0], 2.0 * _array_ops.ones(
#     356             [input_last_dimension - 2 + is_odd], real_dtype),
#     357          _array_ops.ones([1 - is_odd], real_dtype)], 0)
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in ones(shape, dtype, name)
#    3118           # Create a constant if it won't be very big. Otherwise create a fill
#    3119           # op to prevent serialized GraphDefs from becoming too large.
# -> 3120           output = _constant_if_small(one, shape, dtype, name)
#    3121           if output is not None:
#    3122             return output
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in _constant_if_small(value, shape, dtype, name)
#    2802 def _constant_if_small(value, shape, dtype, name):
#    2803   try:
# -> 2804     if np.prod(shape) < 1000:
#    2805       return constant(value, shape=shape, dtype=dtype, name=name)
#    2806   except TypeError:
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    3049     10
#    3050     """
# -> 3051     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3052                           keepdims=keepdims, initial=initial, where=where)
#    3053
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# /afs/ifh.de/group/radio/software/anaconda_p3/envs/jupyter/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in __array__(self)
#     850
#     851   def __array__(self):
# --> 852     raise NotImplementedError(
#     853         "Cannot convert a symbolic Tensor ({}) to a numpy array."
#     854         " This error may indicate that you're trying to pass a Tensor to"
#
# NotImplementedError: Cannot convert a symbolic Tensor (training/Adam/gradients/gradients/loss_1/critic_2_loss/gradients/critic_3/lambda/rfft_grad/irfft_grad/add:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %% [markdown]
# # Analyze results

# %%
noise = np.random.randn(len(data), wgan.latent_size)
noise = np.expand_dims(noise, axis=-1) 
generated_signals = wgan.generator.predict_on_batch(noise)
generated_signals = generated_signals[:,:,0]

# %%
analyze.metrics(data, generated_signals)
# Out:
# Mean generated: -0.013358787633478642
# Mean data: 4.99090109212477e-18
#
# Std generated: 0.9114771485328674
# Std data: 1.0000000000000009

# %%
analyze.plot_traces(data, generated_signals, 5)

# %%
analyze.plot_histograms_time(data, generated_signals)

# %%
analyze.avg_frequencies(data, generated_signals)

# %%
analyze.quantile_frequencies(data, generated_signals)
